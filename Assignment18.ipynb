# %% [markdown]
# <a href="https://colab.research.google.com/github/harshchaturkar/Mini-Project-repo/blob/main/Assignment18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./ford_car_dataset.csv")
df
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
df.head(10)
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0
# 5  Fiesta  2015  10500       Manual    35432   Petrol  145  47.9         1.6
# 6    Puma  2019  22500       Manual     2029   Petrol  145  50.4         1.0
# 7  Fiesta  2017   9000       Manual    13054   Petrol  145  54.3         1.2
# 8    Kuga  2019  25500    Automatic     6894   Diesel  145  42.2         2.0
# 9   Focus  2018  10000       Manual    48141   Petrol  145  61.4         1.0

# %%
df.tail()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 17961  B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962  B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963  Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964     KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965  Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
# 17965         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
# Dataset Structure Observations

# 1. The dataset contains 17,966 rows and 9 columns.
# - Data types: int64, float64, and object.
# - Dataset is suitable for EDA and ML preprocessing.

# %%
-df.duplicated().sum()
# Out:
# np.int64(-154)

# %%
data = df.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.describe())
# Out:
#                year         price        mileage           tax           mpg  \
# count  17966.000000  17966.000000   17966.000000  17966.000000  17966.000000
# mean    2016.866470  12279.534844   23362.608761    113.329456     57.906980
# std        2.050336   4741.343657   19472.054349     62.012456     10.125696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000    9987.000000     30.000000     52.300000
# 50%     2017.000000  11291.000000   18242.500000    145.000000     58.900000
# 75%     2018.000000  15299.000000   31060.000000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17966.000000
# mean       1.350807
# std        0.432367
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplot(3,2,1)
sns.histplot(data['price'])
plt.title("Price")

plt.subplot(3,2,2)
sns.histplot(data['mileage'])
plt.title("Mileage")

plt.subplot(3,2,3)
sns.histplot(data['year'])
plt.title("Year")

plt.subplot(3,2,4)
sns.histplot(data['engineSize'])
plt.title("Engine Size")

plt.subplot(3,2,5)
sns.histplot(data['mpg'])
plt.title("MPG")

plt.tight_layout()

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.countplot(df["fuelType"])
plt.title("fuelType")

plt.subplot(2,2,2)
sns.countplot(df["transmission"])
plt.title("transmission")

plt.subplot(2,2,3)
sns.countplot(df["model"])
plt.title("model")

plt.tight_layout()

# %%
# Market Trend Insights:

# - The category with the highest count is the most common in the market.
# - Petrol cars are more common than other fuel types.
# - Manual and Automatic transmissions are the most popular.
# - Some car models have many more listings than others.
# - Newer cars appear more frequently than older cars.
# - The market mainly consists of affordable, fuel-efficient cars.
# - These plots help identify the most popular car categories and market demand.

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# Observations:
# - Price has a positive correlation with Year.
# - Price has a positive correlation with Engine Size.
# - Price has a negative correlation with Mileage.
# - Price has a negative correlation with MPG.
# - Year and Engine Size are the features most positively related to Price.
# - Mileage is one of the features most negatively related to Price.

# %%
X = data.drop('price', axis=1)

y = data['price']

print("Input Features:")
print(X.columns)

print("\nTarget Feature:")
print(y.name)
# Out:
# Input Features:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# Target Feature:
# price

# %%
# Price is the target feature because we want to predict it.
# All other columns are input features used to predict the price.

# %%
# Categorical columns
print("Before Encoding:")
print(df[['model', 'fuelType']].head())

# One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=['model', 'fuelType'])

print("\nAfter Encoding:")
df_encoded.head()
# Out:
# Before Encoding:
#     model fuelType
# 0  Fiesta   Petrol
# 1   Focus   Petrol
# 2   Focus   Petrol
# 3  Fiesta   Petrol
# 4  Fiesta   Petrol
#
# After Encoding:
#    year  price transmission  mileage  tax   mpg  engineSize  model_B-MAX  \
# 0  2017  12000    Automatic    15944  150  57.7         1.0        False
# 1  2018  14000       Manual     9083  150  57.7         1.0        False
# 2  2017  13000       Manual    12456  150  57.7         1.0        False
# 3  2019  17500       Manual    10460  145  40.3         1.5        False
# 4  2019  16500    Automatic     1482  145  48.7         1.0        False
#
#    model_C-MAX  model_EcoSport  ...  model_S-MAX  model_Streetka  \
# 0        False           False  ...        False           False
# 1        False           False  ...        False           False
# 2        False           False  ...        False           False
# 3        False           False  ...        False           False
# ...

# %%
from sklearn.preprocessing import StandardScaler

num_cols = ['year', 'mileage', 'tax', 'mpg', 'engineSize']

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[num_cols])

scaled_df = pd.DataFrame(scaled_data, columns=num_cols)
print(scaled_df.head())
# Out:
#        year   mileage       tax       mpg  engineSize
# 0  0.067059 -0.382994  0.591380 -0.020597   -0.810561
# 1  0.554393 -0.736317  0.591380 -0.020597   -0.810561
# 2  0.067059 -0.562616  0.591380 -0.020597   -0.810561
# 3  1.041726 -0.665405  0.510777 -1.737858    0.345325
# 4  1.041726 -1.127749  0.510777 -0.908836   -0.810561

# %%
# Data Cleaning
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df

# Histogram
df[['price','mileage','year','engineSize','mpg']].hist(figsize=(8,6))
plt.show()

# Count Plot
sns.countplot(x='transmission', data=df)
plt.show()

# Heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# Input and Output Features
X = df.drop('price', axis=1)
y = df['price']

print("Input Features:")
print(X.columns)

print("\nTarget Feature:")
print(y.name)

# One-Hot Encoding
df = pd.get_dummies(df)

# Feature Scaling
scaler = StandardScaler()
df[['year','mileage','tax','mpg','engineSize']] = scaler.fit_transform(
    df[['year','mileage','tax','mpg','engineSize']]
)

# Final Data
print(df.head())
# Out:
# Input Features:
# Index(['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax', 'mpg',
#        'engineSize'],
#       dtype='object')
#
# Target Feature:
# price
#        year  price   mileage       tax       mpg  engineSize  model_B-MAX  \
# 0  0.067059  12000 -0.382994  0.591380 -0.020597   -0.810561        False
# 1  0.554393  14000 -0.736317  0.591380 -0.020597   -0.810561        False
# 2  0.067059  13000 -0.562616  0.591380 -0.020597   -0.810561        False
# 3  1.041726  17500 -0.665405  0.510777 -1.737858    0.345325        False
# 4  1.041726  16500 -1.127749  0.510777 -0.908836   -0.810561        False
#
#    model_C-MAX  model_EcoSport  model_Edge  ...  model_Tourneo Custom  \
# 0        False           False       False  ...                 False
# 1        False           False       False  ...                 False
# 2        False           False       False  ...                 False
# 3        False           False       False  ...                 False
# ...
